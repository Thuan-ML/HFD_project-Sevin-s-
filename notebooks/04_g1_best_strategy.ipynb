# %%
import pandas as pd

summary_trend = pd.read_pickle("../strategy/summary_trend.pkl")
summary_mr = pd.read_pickle("../strategy/summary_mr.pkl")

comparison_table = pd.concat(
    [summary_trend, summary_mr],
    axis=1
)

comparison_table
# Out:
#                  EMA(20)-EMA(240)  Bollinger S2
# mean_daily_pnl           1.655239      2.150886
# std_daily_pnl           38.856623     10.645013
# sharpe_daily             0.042599      0.202056
# min_daily_pnl         -122.705000    -23.269000
# max_daily_pnl           72.263000     36.875000
# positive_days_%         42.045455     44.318182
# num_days                88.000000     88.000000

# %% [markdown]
# Mean reversion strategy dominates trend following in this sample, delivering higher average returns with substantially lower volatility and superior risk-adjusted performance.
